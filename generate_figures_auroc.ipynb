# %% [markdown]
# ## Generate paper figures using AUROC
#
# Generate versions of main paper figures that use AUROC instead of AUPR.

# %%
import os

from IPython.display import Image, display, SVG
from lxml import etree
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from svgutils.compose import *

import mpmp.config as cfg

# %% [markdown]
# ### Figure 2

# %%
fig_2 = Figure(
    "995", "635",
    etree.Element("rect", {"width": "100%", "height": "100%", "fill": "white"}),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'expression_boxes.svg')).scale(0.85).move(185, 20),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'expression_vs_shuffled.svg')).scale(0.7).move(10, 350),
    Text("A", 185, 20, size=18, weight="bold", font="Verdana"),
    Text("B", 10, 350, size=18, weight="bold", font="Verdana"),
    Text("C", 340, 350, size=18, weight="bold", font="Verdana"),
    Text("D", 665, 350, size=18, weight="bold", font="Verdana"),
)
display(fig_2)

# %% [markdown]
# ### Figure 3

# %%
fig_3 = Figure(
    "1100", "960",
    etree.Element("rect", {"width": "100%", "height": "100%", "fill": "white"}),
    SVG(os.path.join(cfg.images_dirs['data'], 'expression_me_overlap_upset.svg')).scale(0.6).move(15, 20),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'methylation_best_boxes.svg')).scale(0.7).move(425, 30),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'methylation_vs_shuffled.svg')).scale(0.75).move(30, 335),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'methylation_comparison.svg')).scale(0.8).move(20, 640),
    SVG(os.path.join(cfg.images_dirs['survival'], 'me_pancan_survival.svg')).scale(0.75).move(750, 655),
    Text("A", 10, 20, size=18, weight="bold", font="Verdana"),
    Text("B", 430, 20, size=18, weight="bold", font="Verdana"),
    Text("C", 770, 20, size=18, weight="bold", font="Verdana"),
    Text("D", 30, 340, size=18, weight="bold", font="Verdana"),
    Text("E", 395, 340, size=18, weight="bold", font="Verdana"),
    Text("F", 750, 340, size=18, weight="bold", font="Verdana"),
    Text("G", 20, 650, size=18, weight="bold", font="Verdana"),
    Text("H", 395, 650, size=18, weight="bold", font="Verdana"),
    Text("I", 750, 650, size=18, weight="bold", font="Verdana"),
)

display(fig_3)

# %% [markdown]
# ### Figure 4

# %%
fig_4 = Figure(
    "1070", "520",
    etree.Element("rect", {"width": "100%", "height": "100%", "fill": "white"}),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'methylation_genes.svg')).scale(0.7).move(10, 20),
    Text("A", 10, 20, size=18, weight="bold", font="Verdana"),
    Text("B", 360, 20, size=18, weight="bold", font="Verdana"),
    Text("C", 710, 20, size=18, weight="bold", font="Verdana"),
    Text("D", 10, 275, size=18, weight="bold", font="Verdana"),
    Text("E", 360, 275, size=18, weight="bold", font="Verdana"),
    Text("F", 710, 275, size=18, weight="bold", font="Verdana"),
)

display(fig_4)

# %% [markdown]
# ### Figure 5

# %%
fig_5 = Figure(
    "940", "1100",
    etree.Element("rect", {"width": "100%", "height": "100%", "fill": "white"}),
    SVG(os.path.join(cfg.images_dirs['data'], 'all_overlap_upset.svg')).scale(0.5).move(10, 10),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'all_boxes.svg')).scale(0.5).move(500, 10),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'all_vs_shuffled.svg')).scale(0.7).move(30, 350),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'all_comparison.svg')).scale(0.7).move(30, 610),
    SVG(os.path.join(cfg.images_dirs['survival'], 'all_pancan_survival.svg')).scale(0.7).move(250, 860),
    Text("A", 10, 20, size=18, weight="bold", font="Verdana"),
    Text("B", 480, 20, size=18, weight="bold", font="Verdana"),
    Text("C", 480, 175, size=18, weight="bold", font="Verdana"),
    Text("D", 15, 350, size=18, weight="bold", font="Verdana"),
    Text("E", 325, 350, size=18, weight="bold", font="Verdana"),
    Text("F", 630, 350, size=18, weight="bold", font="Verdana"),
    Text("G", 15, 610, size=18, weight="bold", font="Verdana"),
    Text("H", 325, 610, size=18, weight="bold", font="Verdana"),
    Text("I", 630, 610, size=18, weight="bold", font="Verdana"),
    Text("J", 255, 865, size=18, weight="bold", font="Verdana"),
)

display(fig_5)

# %% [markdown]
# ### Figure 6
#
# This is a single figure (not multi-panel) generated in `plot_all_results.ipynb`.

# %%
fig_6 = Figure(
    "1550", "580",
    etree.Element("rect", {"width": "100%", "height": "100%", "fill": "white"}),
    SVG(os.path.join(cfg.images_dirs['mutation'], 'auroc', 'all_heatmap.svg')).scale(0.6).move(10, 20)
)

display(fig_6)

# %% [markdown]
# ### Figure 7

# %%
fig_7 = Figure(
    "750", "830",
    etree.Element("rect", {"width": "100%", "height": "100%", "fill": "white"}),
    SVG(os.path.join(cfg.images_dirs['multimodal'], 'auroc', 'multi_omics_best_model.svg')).scale(0.93).move(10, 20),
    SVG(os.path.join(cfg.images_dirs['multimodal'], 'auroc', 'multi_omics_boxes.svg')).scale(0.5).move(10, 395),
    Text("A", 10, 20, size=18, weight="bold", font="Verdana"),
    Text("B", 10, 395, size=18, weight="bold", font="Verdana"),
    Text("C", 250, 395, size=18, weight="bold", font="Verdana"),
    Text("D", 485, 395, size=18, weight="bold", font="Verdana"),
    Text("E", 10, 615, size=18, weight="bold", font="Verdana"),
    Text("F", 250, 615, size=18, weight="bold", font="Verdana"),
    Text("G", 485, 615, size=18, weight="bold", font="Verdana"),
)

display(fig_7)
